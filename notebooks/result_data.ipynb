# %%
import os
import glob
import pandas as pd

# %%
df_train = pd.read_json("../logs/2022-08-08 04:41:10.624380-train.json")
df_test = pd.read_json("../logs/2022-08-08 04:41:10.626581-test.json")

# %%
df_train
# Out:
#      epoch                        time      loss
# 0        1  2022-08-07 16:15:19.824540  6.309469
# 1        2  2022-08-07 16:16:49.186425  6.259343
# 2        3  2022-08-07 16:18:18.935277  6.258147
# 3        4  2022-08-07 16:19:48.803716  6.254735
# 4        5  2022-08-07 16:21:18.474695  6.248396
# ..     ...                         ...       ...
# 495    496  2022-08-08 04:35:03.895691  6.132434
# 496    497  2022-08-08 04:36:33.516043  6.130176
# 497    498  2022-08-08 04:38:03.047810  6.131142
# 498    499  2022-08-08 04:39:32.640805  6.132016
# 499    500  2022-08-08 04:41:02.303213  6.132223
#
# [500 rows x 3 columns]

# %%
df_test[df_test["epoch"]%50 == 0]
# Out:
#      epoch                        time      loss
# 49      50  2022-08-07 17:28:39.163951  7.493699
# 99     100  2022-08-07 18:43:19.066291  7.474729
# 149    150  2022-08-07 19:58:03.378670  7.479259
# 199    200  2022-08-07 21:12:48.253890  7.477099
# 249    250  2022-08-07 22:27:29.066740  7.469567
# 299    300  2022-08-07 23:42:13.261977  7.469028
# 349    350  2022-08-08 00:56:56.021880  7.470389
# 399    400  2022-08-08 02:11:39.783103  7.465957
# 449    450  2022-08-08 03:26:25.716516  7.474314
# 499    500  2022-08-08 04:41:10.624357  7.470448

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
plt.plot(df_train[df_test["epoch"]%10 == 0]["loss"],'-o')
plt.plot(df_test[df_test["epoch"]%10 == 0]["loss"],'-o')
plt.xlabel('epoch')
plt.ylabel('losses')
plt.legend(['Train','Valid'])
plt.title('Train vs Valid Losses')
plt.figure(figsize=(25,20))

plt.show()

# %%
plt.figure(figsize=(15,10))
# plt.ylim([4,10])
plt.plot(df_train["loss"])
plt.plot(df_test["loss"])
plt.xlabel('epoch')
plt.ylabel('losses')
plt.legend(['Train','Valid'])
plt.title('Train vs Valid Losses')

plt.show()

# %%
df = pd.read_pickle("/mnt/d/sources/data/DL-PTV/merged/3p6.pkl", compression="zip")

# %%
df.head()
# Out:
#             x          y          z        vx        vy        vz  time
# 0 -125.078910  86.888915 -33.059413  0.045851  0.002016 -0.000504   363
# 1 -121.116733  86.888915 -33.059413  0.046023  0.002110 -0.000301   363
# 2 -117.154557  86.888915 -33.059413  0.046189  0.002267 -0.000104   363
# 3 -113.192381  86.888915 -33.059413  0.046358  0.002493  0.000054   363
# 4 -109.230205  86.888915 -33.059413  0.046543  0.002784  0.000152   363

# %%
df1 = df[df["time"] <= 51]

# %%
df["vx"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df1["vx"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df.head()
df["vy"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df1["vy"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df.head()
df["vz"].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df1["vz"].hist(bins=50)
# Out:
# <AxesSubplot:>
